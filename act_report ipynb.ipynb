# %% [markdown]
# # ACT REPORT

# %% [markdown]
# # Analyzing and visualizing the tweet archive of Twitter user @dog_rates, also known as WeRateDogs.

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# My second project with Udacity Data Analyst Nanodegree i worked on  tweet archive of Twitter user @dog_rates, also known as WeRateDogs.¶I gathered  three pieces of data;
# * I was given this twitter_archive_enhanced.csv. file to download and upload by Udacity, Once it was downloaded,i read the data into pandas.
# * A link was made available to programatically download the (image_predictions.tsv) file.
# * I gathered each tweet's retweet count and favorite ("like") count at the minimum using the tweet IDs in the WeRateDogs Twitter archive, queried the Twitter API for each tweet's JSON data using Python's Tweepy library and stored each tweet's entire set of JSON data in a file called tweet_json.txt file.

# %% [markdown]
# <img src='visuals/dogpic1.png'>

# %% [markdown]
# This report is to presents insights gotten from analyzing the three datasets.

# %% [markdown]
# #### Research Questions
# * Most common dog group
# * What dog group got the highest highest retweet counts and favourite count?
# * What are the top 5 predicted dog breeds with the highest retweet count?
# * Top 5 most popular dog names.
# * What is the relationship between dog rating, retweet count and favourite count?

# %% [markdown]
# #### Insight 1 what is the most common dog group

# %% [markdown]
# <img src='visuals/visz1.png'>

# %% [markdown]
# #### Insights 2 What dog group the most common, have the highest dog rating, retweet counts(popular) and favourite count(loved)?
# Average Dog rating of 1.2 is the same for all dog groups except pupper which just slightly lower.Puppo and Doggo are the most loved dog groups, they are also the most popular dog gropus.

# %% [markdown]
# <img src='visuals/visz2.png'>

# %% [markdown]
# <img src='visuals/visz4.png'>

# %% [markdown]
# <img src='visuals/visz5.png'>

# %% [markdown]
# #### Insights 3 What are the top 5 predicted dog breeds?
# Top five most common dog breeds that are pedicted are golden_retriever, labrador_retriever, pembroke, chihuahua and pug.

# %% [markdown]
# <img src='visuals/visz6.png'>

# %% [markdown]
# #### Insights 1 What dog breed got the highest dog rating, retweet counts(popular) and favourite count(loved)?
# Beddington_terrier, Afghan_hound, French_Bulldog, bourrier_des_flandres, Saluki are the most loved breed.Similary,Beddington_terrier, Afghan_hound, Standard_poodle, English_springer, Saluki are the most retweeted breed.
#
# Dumber has a very high and unsual rating above 2.5,next is bouvier_des_flandres with about 1.3, tibeten_mastiff, briard, Saluki, and lastly the bouvier_des_flandres all have abot 1.2 rating.

# %% [markdown]
# <img src='visuals/visz7.png'>

# %% [markdown]
# <img src='visuals/visz8.png'>

# %% [markdown]
# <img src='visuals/visz9.png'>

# %% [markdown]
# #### Insights 4 Top 10 most popular dog names.
# Cooper, lucy, Charlie, Tucker, Oliver, Peny etc. are the common(trendy) names given to dogs.

# %% [markdown]
# <img src='visuals/visz10.png'>

# %% [markdown]
# #### Insights 5: What is the relationship between dog rating, retweet count and favourite count?
# There is a very strong positive correlation between favorite count and retweet count(i.e.The higher the fovorite count the higher the retweet count), Futhermore there is a weak positive corellation between dog_rating and favourite count also retweet count(i.e. a higher dog rating does not necessary guarantee popularity)

# %% [markdown]
# <img src='visuals/visz11.png'>

# %% [markdown]
# <img src='visuals/visz12.png'>

# %% [markdown]
# <img src='visuals/visz13.png'>

# %% [markdown]
# <img src='visz14.png'>

# %%
from subprocess import call
call (['python','-m','nbconvert','act_report.ipynb'])
# Out:
# 0
